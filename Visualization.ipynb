# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('nba.csv')
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
df['Height'].hist(bins=10)
# Out:
# <Axes: >

# %%
df.boxplot(column='Salary', by='Team')
# Out:
# <Axes: title={'center': 'Salary'}, xlabel='Team'>

# %%
x=df['Age']
y=df['Salary']
plt.scatter(x,y, color='r', s=30)
plt.show()

# %%
df['Age'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('ggplot')
df['Age'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('bmh')
df['Age'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
df['Age'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('fivethirtyeight')
df['Age'].hist()
# Out:
# <Axes: >

# %%
df['Age'].plot.line()
# Out:
# <Axes: >

# %%
df['Age'].plot.area(alpha=0.4)
# Out:
# <Axes: >

# %%
df['Number'].plot.bar()
# Out:
# <Axes: >

# %%
df['Number'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.scatter(x='Age', y='Salary', c ='c', cmap ='coolwarm')
# Out:
# C:\Users\rfare\miniconda3\envs\python-for-data-analysis\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1345: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
df[['Salary','Age','Height']].plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns =['a', 'b']) 
df.plot.hexbin(x ='a', y ='b', gridsize = 25, cmap ='Oranges')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df=pd.read_csv('nba.csv')
df['Salary'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.density()
# Out:
# <Axes: ylabel='Density'>
